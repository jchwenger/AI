# %% [markdown]
# # Attendance
#
# [The link to SEAts](https://gold.seats.cloud/angular/#/lectures)

# %% [markdown]
# ----
#
# # 8 Introduction to deep learning for computer vision
#
# - ### Convolution & Pooling operations
# - ### Data augmentation
# - ### Feature extraction with a pretrained net
# - ### Fine-tuning a pretrained net

# %%
import os
import shutil
import pathlib

import numpy as np
import tensorflow as tf

import matplotlib.pyplot as plt

# %% [markdown]
# ## 8.1 Introduction to convnets

# %% [markdown]
# This topic introduces a new type of layer: the **convolutional layer**.
#
# Convnets – models with convolutional layers – are first-call choices for computer vision DL applications (although the competition with Transformers is steep these days).

# %% [markdown]
# We will learn:
#
# - What are convnets, how do they work?
# - Build one and train it on with a small training set;
# - Use of powerful pretrained convnets;
# - Visualise what convnets learn.

# %% [markdown]
# We begin with a simple convnet for the MNIST task.
#
# A few lines of code.
#
# It easily outperforms our previous dense-layer models.

# %%
inputs = tf.keras.Input(shape=(28, 28, 1)) # notice the functional syntax! ↓
x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu")(inputs)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.Flatten()(x)
outputs = tf.keras.layers.Dense(10, activation="softmax")(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs) # ← we define the model by providing inputs and outputs

# %% [markdown]
# A stack of `Conv2D` and `MaxPooling2D` layers: we learn about these today.
#
# A convnet accepts input tensors of shape (excluding the batch dimension):
#
# ```
# (image_height, image_width, image_channels) # channels: RGB colors
# ```
# Here:
# ```python
# x = tf.keras.Input(shape=(28, 28, 1)) # MNIST is b&w: 1 channel
# ```

# %% [markdown]
# Functional syntax with the `tf.keras.Model`.
#
# A `Model` is instantiated from:
# - an input tensor (or list of input tensors) and
# - an output tensor (or list of output tensors).
#
# These class models are more flexible than the `Sequential` model of our earlier topics.
#
# `tf.keras.Sequential()` instantiates a model that requires exactly one input and one output.
#
# `tf.keras.Model()` models can have multiple inputs and outputs – more in Topic 7: Advanced Practices.

# %%
model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (None, 26, 26, 32)          │             320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (None, 11, 11, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (None, 5, 5, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (None, 3, 3, 128)           │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 1152)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 10)                  │          11,530 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 104,202 (407.04 KB)
#  Trainable params: 104,202 (407.04 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# Every `Conv2D` and `MaxPooling2D` layer output is a 3D tensor of shape:
# ```
# (height, width, channels)
# ```
#
# Notice how the width and height dimensions shrink along the processing pipeline, just as the channels increase.
#
# `Conv2D` layer parameters:
#
# ```python
# x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
# ```
# 64 channels, a 3 x 3 **kernel**, relu activation.

# %% [markdown]
# The final convolution output (of shape `(3, 3, 128)`) must be fed into a densely-connected classifier.
#
# `Dense` layer classifiers process 1D vectors – the convnet output is a 3D tensor.
#
# We `Flatten` our 3D output to 1D, and then add a `Dense` layer on top.
#
# The `(3, 3, 128)` convnet output is flattened into a  `(3 * 3 * 128,) = (1152,) ` vector.
#
# Then it is passed into a `Dense` layer with a `softmax` activation.

# %%
(train_images, train_labels), (test_images, test_labels) = tf.keras.datasets.mnist.load_data()
train_images = train_images.reshape((60000, 28, 28, 1))
train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28, 28, 1))
test_images = test_images.astype("float32") / 255

# %%
model.compile(optimizer="rmsprop",loss="sparse_categorical_crossentropy",metrics=["accuracy"])

test_loss, test_acc = model.evaluate(test_images, test_labels, verbose=0)
print(f"Test accuracy: {test_acc:.3f} ... (⌒_⌒;) ")
# Out:
# Test accuracy: 0.101 ... (⌒_⌒;)

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=64)

test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"Test accuracy: {test_acc:.3f} (¬‿¬ )") # better than dense nets with the same amount of params!
# Out:
# Epoch 1/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 10s 4ms/step - accuracy: 0.8846 - loss: 0.3645
# Epoch 2/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9838 - loss: 0.0492
# Epoch 3/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9903 - loss: 0.0314
# Epoch 4/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9933 - loss: 0.0207
# Epoch 5/5
# 938/938 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9949 - loss: 0.0161
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.9870 - loss: 0.0399
# Test accuracy: 0.990 (¬‿¬ )

# %% [markdown]
# ----
#
# ## 8.1.1 The convolution operation

# %% [markdown]
# Previously, we built fully-connected (dense layered) feedforward networks.
#
# The architecture does not match the **local structure** of the images.
#
# Pixels that are far apart have the same influence as pixels that are close.
#
# But images typically do have **local structure** (edges, corners, shading etc).
#
# And these local patterns are **repeated** throughout the image.

# %% [markdown]
# Convolutional nets respect **translational invariance** of image detail.
#
# That means: they can learn features **regardless of where they appear in the image**.
#
# They are **smaller** than dense models and **faster** to train.
#
# That is because the number of parameters can remain the same **no matter the size of the image**.
#
# They are the natural choice for deep learning computer vision.
#
# (At least until Transformers come along...)

# %% [markdown]
# Let's take our well-known MNIST sample: a 28 x 28 greyscale array, as an input.
#
# Now, a unit/neuron in the first hidden (convolutional) layer is connected to patches of $9 = 3 x 3$ inputs
# (in the first layer: pixels, in general: neurons/units).
#
# Each of those patches, when scanned by our kernel, is known as its **local receptive field**.
#
# It is what the kernel 'sees' at any one point.

# %% [markdown]
# Each kernel element (a connection) is one weight, and there is a **single bias**. 10 learnable parameters.
#
# The **kernel** is repeated by shifting it one pixel at a time (over many patches or **local receptive fields**).
#
# Each time, the same operation occurs: an **element-wise product** between the layer weights and the patch, followed by a **sum** (then the bias is added).
#
# <!-- <img style="float:right" src="images/convolutions/conv-1.gif" style="width: auto;"> -->
# <img style="float:right" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/convolutions/conv-1.gif?raw=true">
#
# <small style="position:absolute;bottom:0;right:0">[Irhum Shafkat, Intuitively Understanding Convolutions for Deep Learning](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1)</small>

# %% [markdown]
# As the the kernel is moved across the image, being exposed to different patches (local receptive fields), its **weights remain the same**.
#
# In a way it's as if we were 'summarising' local information (3x3) in one number (literally a *weighted* sum).
#
# *This is the same operation as a blur in image processing or a filter in sound processing.*
#
# <!-- <img style="float:right" src="images/convolutions/conv-2.gif" style="width: auto;"> -->
# <img style="float:right" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/convolutions/conv-2.gif?raw=true">
#
# <small style="position:absolute;bottom:0;right:0">Source: [Irhum Shafkat, Intuitively Understanding Convolutions for Deep Learning](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1)</small>

# %% [markdown]
# Note that you don't *have* to move by one! You can increase that parameter.
#
# This is called the **stride**.
#
# Here a stride of 2, where we skip every other position:
#
# <!-- <img style="float:right" src="images/convolutions/conv-4.gif"> -->
# <img style="float:right" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/convolutions/conv-4.gif?raw=true">
#
#
# <small style="position:absolute;bottom:0;right:0">Source: [Irhum Shafkat, Intuitively Understanding Convolutions for Deep Learning](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1), originally from [Dumoulin and Visin, A guide to convolution arithmetic for deep learning](https://arxiv.org/abs/1603.07285) ([github](https://github.com/vdumoulin/conv_arithmetic))</small>

# %% [markdown]
# Note also that if you need the output of this operation to keep the dimensions the same, you need to **pad** the input (usually with zeros).
#
# <!-- <img style="float:right" src="images/convolutions/conv-3.gif"> -->
# <img style="float:right" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/convolutions/conv-3.gif?raw=true">
#
# <small style="position:absolute;bottom:0;right:0">Source: [Irhum Shafkat, Intuitively Understanding Convolutions for Deep Learning](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1), originally from [Dumoulin and Visin, A guide to convolution arithmetic for deep learning](https://arxiv.org/abs/1603.07285) ([github](https://github.com/vdumoulin/conv_arithmetic))</small>

# %% [markdown]
# The (not so great) vocabulary for both of these is:
# - `valid` (= no padding: only **valid** positions in the input are used);
# - `same` (= with padding: the output dimension is the **same** as the input).

# %% [markdown]
# As you can see, the vanilla operation will reduce the size of the image.
# This is the equation for it (assuming a square input and and a square kernel):
#
# $$
# \bbox[5px,border:2px solid red]{
#     output\_size = \frac{input\_size\ -\ kernel\_size + 2\times padding}{stride} + 1
# }
# $$
#
# If padding is zero and stride one, this simplifies to:
#
#
# $$
#  \bbox[5px,border:2px solid red]{
#     output\_size = input\_size\ -\ kernel\_size + 1
# }
# $$

# %% [markdown]
# The weights and bias ($3 \times 3 + 1 = 10$ params in our example) do not change even though the local receptive field sweeps across the image.
#
# Those weights and bias, the **kernel**'s, are *learnt* – they specialise in detecting a single **feature**.
#
# What is a feature? Perhaps an edge? The beauty is: this emerges from training.
#
# It can detect this same feature (edge) anywhere in the image – that's how the convolutional layer respects the **local image structure** (translational invariance).

# %% [markdown]
# You can think of this operation as runnning some sort of **detector** over the image.
#
# One kernel (detector) will look for one specific feature. For instance, vertical edges:
#
# <!-- <img style="float:right; height:500px" src="images/convolutions/conv-5-edge-detector.png"> -->
# <img style="float:right" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/convolutions/conv-5-edge-detector.png?raw=true">
#
# <small style="position:absolute;bottom:0;right:0">Source: [Irhum Shafkat, Intuitively Understanding Convolutions for Deep Learning](https://towardsdatascience.com/intuitively-understanding-convolutions-for-deep-learning-1f6f42faee1)</small>

# %% [markdown]
# The result (filter) is a **feature map**, mapping the 28 x 28 input image features to a smaller, 24 x 24 dimensional 'image'.
#
# You can think of this as a *geographical map*: the image is the actual territory, the *map* tells you where features are (beaches, rivers, treasure, dangers, etc.).
#
# Your kernel scans the territory searching for a particular feature.

# %% [markdown]
# Finally, because we want to detect many different **features**, we repeat the process with **several kernels** on the same image.
#
# *A colour image has three channels. You could view the feature maps as __one__ image with many channels*...
#
# <!-- <img style="float:right" src="images/CNN.png" style="width: auto;"> -->
# <img style="float:right" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/CNN.png?raw=true">
#
# <small style="position:absolute;bottom:0;right:0">Source: [Md Zahangir Alom et al., "A State-of-the-Art Survey on Deep Learning Theory
# and Architectures", Researchgate](https://www.researchgate.net/figure/The-overall-architecture-of-the-Convolutional-Neural-Network-CNN-includes-an-input_fig4_331540139)</small>

# %% [markdown]
# ```python
# x = tf.keras.layers.Conv2D(
#     filters=64,        # filters/kernels: 64
#     kernel_size=3,     # kernel: 3x3 | specify each axis with a tuple: (1,2)
#     strides=2,         # strides: by how much you slide | tuples also work
#     activation="relu", # activation after operation
#     padding="same"     # padding: "same" or "valid"
# )(x)
# ```
#
# As usual, many more options and tweaks you can find in the [TF Keras reference](https://www.tensorflow.org/api_docs/python/tf/keras/layers/Conv2D).

# %% [markdown]
# ----
#
# ## 8.1.2 The max-pooling operation

# %% [markdown]
# Convnets also contain pooling layers, which are basically just **downsampling**.
#
# Pooling layers are usually used immediately after convolutional layers.
#
# Pooling layers simplify the information from the preceding convolutional layer.

# %% [markdown]
# For instance, each unit in the pooling layer may summarize a 2 x 2 patch in the previous layer.
#
# In *max-pooling*, a pooling unit simply outputs the **maximum activation** in the 2 × 2 input region.
#
# There are 4 x 4 neurons in the depicted input layer;
# 2 x 2 neurons in the pooling layer: the feature map is halved in size.
#
#
# See [here](https://www.tensorflow.org/api_docs/python/tf/keras/layers/MaxPooling2D) for equations in all cases.
#
# <!-- ![Francis max-pooling](images/convolutions/max-pooling.gif) -->
# <img style="float:right" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/convolutions/max-pooling.gif?raw=true">
#
# <small style="position:absolute;bottom:0;right:0">Source: [Justin Francis, Visualizing convolutional neural networks, O'Reilly](https://www.oreilly.com/radar/visualizing-convolutional-neural-networks/)</small>

# %% [markdown]
# Max-pooling is applied to each feature map separately.
#
# With convolution, the number of channels is transformed into a **different** number of feature maps.
# With max-pooling, each feature map is reduced in size (**same number of feature maps**).
#
# <!-- <img style="float:right" src="images/CNN.png" style="width: auto;"> -->
# <img style="float:right" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/CNN.png?raw=true">
#
#
# <small style="position:absolute;bottom:0;right:0">Source: [Md Zahangir Alom et al., "A State-of-the-Art Survey on Deep Learning Theory
# and Architectures", Researchgate](https://www.researchgate.net/figure/The-overall-architecture-of-the-Convolutional-Neural-Network-CNN-includes-an-input_fig4_331540139)</small>

# %% [markdown]
# **Common pattern**
#
# - 3 x 3 kernels, stride 1
# - 2 x 2, max-pooling, stride 2

# %% [markdown]
# Also possible, but less common: *min-*, *average-* pooling.
#
#
# Max-pooling is arguably preferential – the **maximal presence** of a feature is more informative.
#
# Rather than risk diluting its presence by taking an average.
#
# The intuition behind any type of pooling is similar: pooling is a way of **condensing information**.

# %% [markdown]
# Pooling not only **downsamples** (therefore less parameters) but it also **widens the effective receptive field** seen by the next layer.
#
# *For example, in 2 x 2, stride 2 pooling, a 6 x 6 patch coming out of the previous conv layer is reduced to a 3 x 3 patch in the pooling layer. This 3 x 3 patch is seen by a single neuron in the next layer. The neuron's field of vision has increased from 3 x 3 to 6 x 6.*
#
# In the figure, the neuron in layer 3 'sees' the whole image in layer 1 after the layer 2 downsampling:
#
# <!-- <img  style="float:right" src="images/convolutions/receptive-field.png"> -->
# <img style="float:right" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/convolutions/receptive-field.png?raw=true">
#
#
# <small style="position:absolute;bottom:0;right:0">[Xu et al., "MSF-Net: Multi-Scale Feature Learning Network for Classification of Surface Defects of Multifarious Sizes", ResearchGate](https://www.researchgate.net/figure/Schematic-diagram-of-the-receptive-field-in-CNNs_fig1_353545214)</small>

# %% [markdown]
# ## Why convolutions?

# %% [markdown]
# Let's calculate the number of parameters in the first layers of our convnet:

# %%
inputs = tf.keras.Input(shape=(28,28, 1))
x = tf.keras.layers.Conv2D(32, kernel_size=3, activation='relu')(inputs)
model = tf.keras.Model(inputs, x)
model.summary() # 320 params
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)           │ (None, 28, 28, 1)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (None, 26, 26, 32)          │             320 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 320 (1.25 KB)
#  Trainable params: 320 (1.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
32 * (3 * 3 + 1) # number of params
# Out:
# 320

# %% [markdown]
# For comparison: the input layer of our earlier MNIST model:

# %%
inputs = tf.keras.Input(shape=(28*28,))
x = tf.keras.layers.Dense(512, activation='relu')(inputs)
model = tf.keras.Model(inputs, x)
model.summary() # 401'920 params
# Out:
# Model: "functional_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, 784)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 512)                 │         401,920 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 401,920 (1.53 MB)
#  Trainable params: 401,920 (1.53 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
f"{512 * (28 * 28 + 1):,}" # number of params
# Out:
# '401,920'

# %% [markdown]
# ----
#
# ## 8.2 Training a convnet on a small dataset

# %% [markdown]
# Small means dataset sizes of a few hundreds to a few tens of thousands of images.
#
# A common computer vision situation.
#
# In our case: a cat or a dog?

# %% [markdown]
# ### The Dogs vs Cats dataset

# %% [markdown]
# 4000 images of cats and dogs (2000 cats, 2000 dogs)
#
# Split: 2000 images for training, 1000 for validation, 1000 for testing

# %% [markdown]
# This is a balanced binary classification problem.
#
# The **commonsense baseline** prediction accuracy is 50%.
#
# We will also train a small convnet on our 2000 training samples, without any regularization, to set a 'neural' baseline for what can be achieved.

# %% [markdown]
# #### Note

# %% [markdown]
# The original dataset contains 25,000 images of dogs and cats (12,500 from each class).

# %% [markdown]
# 1. We will find that our second, CNN baseline classification accuracy of $\approx$72%.
#   (At that point, our main issue will be overfitting.)
#
# 2. We will fight overfitting with **data augmentation** and reach an accuracy of $\approx$79%.
#
# 3. Then we will review two more essential techniques applicable to small datasets:
#   - **feature extraction** with a pretrained network => 96% accuracy;
#   - **fine-tuning** a pretrained network => almost 97% final accuracy.
#
# *(Chollet has a larger gap between the last two, I could not reproduce it. Please tell me if you can!)*

# %% [markdown]
# ----
#
# ## 8.2.1 DL and  small-data problems

# %% [markdown]
# Deep Learning requires masses of data? Basically correct.
#
# It replaces time consuming manual feature engineering with automatic training
# – but the price is needing large datasets.
#
# This is especially true for high-dimensional inputs.

# %% [markdown]
# What size of dataset is sufficient?
#
# This depends on the size and depth of the network and the difficulty and the complexity of the task.
#
# Training on a few hundred samples is feasible if:
# - the network is small and regularised;
# - the task is simple.

# %% [markdown]
# Deep Learning models are fairly malleable: an image classification or speech-to-text model trained on a large-scale dataset can be reused on a significantly different problem with only minor changes.
#
# Many pretrained computer vision models (usually trained on the ImageNet dataset) are now publicly available and can bootstrap powerful CV models with very little new data.

# %% [markdown]
# Remember me saying the **distributions** of the data must be the same in **training** and **production**?
#
# Here we assume that the net has trained on enough data to covers what we need.
#
# Despite being trained on a different image dataset, these pretrained models are useful because spatial features tend to be **generic** (edges, corners, etc).
#
# We turn a *generalist* network into a *specialist* one.

# %% [markdown]
# ----
#
# ## 8.2.2 Downloading the data

# %% [markdown]
# <img style="height:620px;float:right" src="https://s3.amazonaws.com/book.keras.io/img/ch5/cats_vs_dogs_samples.jpg">
#
# The images are medium-resolution color JPEGs.

# %% [markdown]
# ### Recommended Workflow

# %% [markdown]
# The dataset is available on [Kaggle](https://www.kaggle.com/c/dogs-vs-cats/data), and DLWP has a procedure to download it in Colab (pp.212-213):
#
# 1. Create a Kaggle account (free)
# 2. Go to [settings](https://www.kaggle.com/settings), create a token (`.json` file), download it locally and upload it to the main Colab folder. The code below expects that.

# %% [markdown]
# #### Integration with Google Colab

# %% [markdown]
# One additional possibility is to upload the `kaggle.json` file to your Google Drive, then connect this notebook to it and copy it from there.

# %%
IMPORT = False
if IMPORT:
    from google.colab import drive
    drive.mount('/content/drive')
    # copy file from drive
    # !cp "drive/MyDrive/IS53024B-Artificial-Intelligence/kaggle.json" .

# %% [markdown]
# #### Note

# %% [markdown]
# The [Dogs vs Cats dataset](https://www.tensorflow.org/datasets/catalog/cats_vs_dogs) is available in the separate Tensorflow Dataset package, but there's a still unresolved bug in there, corrupted images...

# %% [markdown]
# ### Data download & processing

# %%
DATASET_DIR = pathlib.Path("dogs-vs-cats")
ORIG_TRAIN_DIR = DATASET_DIR / "train"
SMALL_DS_DIR = DATASET_DIR / pathlib.Path("dogs_vs_cats_small")

# %%
kaggle_auth = False
if os.path.isfile("kaggle.json"):
    print("Found token file `kaggle.json`")
    # !mkdir -p /root/.config/kaggle
    # !cp kaggle.json /root/.config/kaggle
    # !chmod 600 /root/.config/kaggle/kaggle.json
    kaggle_auth = True
else:
    print("Could not token file `kaggle.json`, please see the steps above!")
# Out:
# Found token file `kaggle.json`

# %%
if not DATASET_DIR.exists() and kaggle_auth:
    # !kaggle competitions download -c dogs-vs-cats
    # !unzip -q dogs-vs-cats -d dogs-vs-cats
    # !unzip -q dogs-vs-cats/train.zip -d dogs-vs-cats/

# %%
def make_subset(subset_name, start_index, end_index):
    for category in ("cat", "dog"):
        small_dir = SMALL_DS_DIR / subset_name / category # sweet Pathlib syntax
        if not os.path.isdir(small_dir):
            os.makedirs(small_dir, exist_ok=True)
        if len(os.listdir(small_dir)) == end_index - start_index:
            # we reached the desired number of images
            return
        fnames = [f"{category}.{i}.jpg" for i in range(start_index, end_index)]
        # print(fnames)
        for fname in fnames:
            shutil.copyfile(src=ORIG_TRAIN_DIR / fname,
                            dst=small_dir / fname)
        else:
            print(f"found {small_dir}, done.")

# %%
make_subset("train", start_index=0, end_index=1000)
make_subset("validation", start_index=1000, end_index=1500)
make_subset("test", start_index=1500, end_index=2500)

TRAIN_DIR = SMALL_DS_DIR / "train"
VAL_DIR = SMALL_DS_DIR / "validation"
TEST_DIR = SMALL_DS_DIR / "test"
TRAIN_CATS_DIR = TRAIN_DIR  / "cat"
VAL_CATS_DIR = VAL_DIR  / "cat"
TEST_CATS_DIR = TEST_DIR  / "cat"
TRAIN_DOGS_DIR = TRAIN_DIR  / "dog"
VAL_DOGS_DIR = VAL_DIR  / "dog"
TEST_DOGS_DIR = TEST_DIR  / "dog"

# As a sanity check, let's count how many pictures we have in each sub-dataset:
print("-" * 40)
print('total training cat images:', len(os.listdir(TRAIN_CATS_DIR)))
print('total training dog images:', len(os.listdir(TRAIN_DOGS_DIR)))
print('total validation cat images:', len(os.listdir(VAL_CATS_DIR)))
print('total validation dog images:', len(os.listdir(VAL_DOGS_DIR)))
print('total test cat images:', len(os.listdir(TEST_CATS_DIR)))
print('total test dog images:', len(os.listdir(TEST_DOGS_DIR)))
# Out:
# ----------------------------------------
# total training cat images: 1000
# total training dog images: 1000
# total validation cat images: 500
# total validation dog images: 500
# total test cat images: 1000
# total test dog images: 1000

# %% [markdown]
# ----
#
# ## 8.2.3 Building the model

# %% [markdown]
# Our convnet is a stack of alternating `Conv2D` (with `relu` activation) and `MaxPooling2D` layers.
#
# The problem is more complex than MNIST (bigger images), we need a bigger convnet.
#
# ⇒ One more `Conv2D` + `MaxPooling2D` than in the first one:
#
# - augments the capacity of the network;
# - reduces the size of the feature maps: they are not too large when reaching the `Flatten` layer.

# %%
inputs = tf.keras.Input(shape=(150, 150, 3))
x = tf.keras.layers.Rescaling(1./255)(inputs) # ←---------------------------  PIXEL VALUE NORMALISATION!
x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
# -------------------------------------------------------------------------- ↓ MORE LAYERS THAN BEFORE
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
# -------------------------------------------------------------------------- ↑ MORE CAPACITY & SMALLER FEATURE MAPS
x = tf.keras.layers.Flatten()(x)
outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs)

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)           │ (None, 150, 150, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ rescaling (Rescaling)                │ (None, 150, 150, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (None, 148, 148, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (None, 74, 74, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (None, 72, 72, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (None, 36, 36, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_6 (Conv2D)                    │ (None, 34, 34, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (None, 17, 17, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 15, 15, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (None, 7, 7, 256)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_8 (Conv2D)                    │ (None, 5, 5, 256)           │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_1 (Flatten)                  │ (None, 6400)                │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │           6,401 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 984,897 (3.76 MB)
#  Trainable params: 984,897 (3.76 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 150 x 150 image input size (an arbitrary choice) is reduced to 5 x 5:
#
# - the depth of the feature maps (number of channels/filters per layer) progressively increases (from 32 to 256);
# - the size of the feature maps decreases (from 148 x 148 to 5 x 5).
#
# **Increasing depth** and **decreasing feature map size** is a common convnet architectural pattern.

# %% [markdown]
# **Binary classification problem**
#
# The network ends in a single `sigmoid` unit and outputs: the probability that the network is looking at one class or the other.
#
# **Metric**
#
# We track the accuracy.

# %%
model.compile(
    loss="binary_crossentropy", # binary classification: one class or the other
    optimizer="rmsprop",        # RMSprop as usual
    metrics=["accuracy"],       # our metric
)

# %% [markdown]
# ----
#
# ## 8.2.4 Data preprocessing

# %% [markdown]
# Our data must be vectorised into floating point tensors.
#
# The data are JPEG files. The pipeline is then:
#
# - read the picture files;
# - decode the JPEG content to RGB grids of pixels;
# - resize them to a shared size `(150, 150)`;
# - convert to floating point tensors;
# - (The rescaling of pixel values to $[0, 1]$ is dealt by the network itself, the `Rescaling` layer).

# %% [markdown]
# There are many processing helper tools in `tensorflow.keras.utils`.
#
# Including an `image_dataset_from_directory` ([documentation](https://www.tensorflow.org/api_docs/python/tf/keras/utils/image_dataset_from_directory)), which can automatically turn image files on disk into batches of preprocessed tensors, assigning classes according to the directory structure!
#
# ```bash
# $ tree -d 1 dogs-vs-cats
# ├── dogs_vs_cats_small
# │   ├── test
# │   │   ├── cat
# │   │   └── dog
# │   ├── train
# │   │   ├── cat
# │   │   └── dog
# │   └── validation
# │       ├── cat
# │       └── dog
#
# ```

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
    SMALL_DS_DIR / "train",
    image_size=(150, 150),
    batch_size=32
)
validation_dataset = tf.keras.utils.image_dataset_from_directory(
    SMALL_DS_DIR / "validation",
    image_size=(150, 150),
    batch_size=32
)
test_dataset = tf.keras.utils.image_dataset_from_directory(
    SMALL_DS_DIR / "test",
    image_size=(150, 150),
    batch_size=32
)
# Out:
# Found 2000 files belonging to 2 classes.
# Found 1000 files belonging to 2 classes.
# Found 2000 files belonging to 2 classes.

# %% [markdown]
# The batch size (samples per batch) is set to 32.
#
# The generators yield batches of:
# - 150 x 150 RGB images (shape: `(32, 150, 150, 3)`) and
# - binary labels (shape: `(32,)`).

# %% [markdown]
# ---
#
# ### Understanding TensorFlow Dataset objects

# %% [markdown]
# TensorFlow datasets create iterables that can be fed to networks. There are many functionalities available, including batching, shuffling, custom filtering and transformations of datasets, caching and prefetching for memory optimisation, etc.
#
#
# The official [tutorial](https://www.tensorflow.org/api_docs/python/tf/data/Dataset).

# %%
random_numbers = np.random.normal(size=(1000, 16))
dataset = tf.data.Dataset.from_tensor_slices(random_numbers)

# %%
for i, element in enumerate(dataset):
    print(element.shape)
    if i >= 2:
        break
# Out:
# (16,)
# (16,)
# (16,)

# %%
batched_dataset = dataset.batch(32)
for i, element in batched_dataset.enumerate():
    print(element.shape)
    if i >= 2:
        break
# Out:
# (32, 16)
# (32, 16)
# (32, 16)

# %%
reshaped_dataset = dataset.map(lambda x: tf.reshape(x, (4, 4)))
for i, element in reshaped_dataset.enumerate():
    print(element.shape)
    if i >= 2:
        break
# Out:
# (4, 4)
# (4, 4)
# (4, 4)

# %%
for data_batch, labels_batch in train_dataset:
    print("data batch shape:", data_batch.shape)
    print("labels batch shape:", labels_batch.shape)
    break
# Out:
# data batch shape: (32, 150, 150, 3)
# labels batch shape: (32,)

# %% [markdown]
# - `.shuffle(buffer_size)`: shuffles elements within a buffer;
# - `.map(callable)`: applies an arbitrary transformation to each element of the dataset (the function callable, which expects to take as input a single element yielded by the dataset);
# - `.filter(callable)`: applies a transformation to remove certain elements;
# - `.cache()`: caches elements the first time the dataset is iterated over;
# -  `.prefetch(buffer_size)`: prefetches a buffer of elements in GPU memory to achieve better device utilization (while e.g. model computation is going on).
#
# ---
#
# Note the use of the [`ModelCheckpoint` callback](https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/ModelCheckpoint) to save our model just below!

# %%
MODELS_DIR = pathlib.Path("models")
MODELS_DIR.mkdir(exist_ok=True)

# %%
callbacks = [       #  ↓ a callback to save our best model!
    tf.keras.callbacks.ModelCheckpoint(
        filepath= str(MODELS_DIR / "convnet_from_scratch.keras"), # name of the file
        save_best_only=True,                                        # if False you can use save_freq to save every n epochs
        monitor="val_loss"                                          # what metric to monitor
    )
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks
)

del model
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 13s 119ms/step - accuracy: 0.5090 - loss: 0.6991 - val_accuracy: 0.5000 - val_loss: 0.6925
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.5259 - loss: 0.6971 - val_accuracy: 0.6290 - val_loss: 0.6794
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.5655 - loss: 0.6895 - val_accuracy: 0.6430 - val_loss: 0.6709
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.6111 - loss: 0.6696 - val_accuracy: 0.5800 - val_loss: 0.6608
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 78ms/step - accuracy: 0.6546 - loss: 0.6312 - val_accuracy: 0.6640 - val_loss: 0.6125
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.6993 - loss: 0.5821 - val_accuracy: 0.6720 - val_loss: 0.6258
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.7130 - loss: 0.5484 - val_accuracy: 0.6330 - val_loss: 0.6126
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 68ms/step - accuracy: 0.7367 - loss: 0.5137 - val_accuracy: 0.6220 - val_loss: 0.6826
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 75ms/step - accuracy: 0.7481 - loss: 0.5155 - val_accuracy: 0.7350 - val_loss: 0.5172
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.7957 - loss: 0.4499 - val_accuracy: 0.7530 - val_loss: 0.5211
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8106 - loss: 0.4150 - val_accuracy: 0.7350 - val_loss: 0.5631
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.8270 - loss: 0.3744 - val_accuracy: 0.7450 - val_loss: 0.5559
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.8604 - loss: 0.3280 - val_accuracy: 0.7300 - val_loss: 0.7431
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.8977 - loss: 0.2793 - val_accuracy: 0.7330 - val_loss: 0.7398
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9085 - loss: 0.2308 - val_accuracy: 0.7440 - val_loss: 0.7364
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 46ms/step - accuracy: 0.9371 - loss: 0.1671 - val_accuracy: 0.7280 - val_loss: 0.9279
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9476 - loss: 0.1304 - val_accuracy: 0.7090 - val_loss: 0.9362
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9320 - loss: 0.1746 - val_accuracy: 0.7030 - val_loss: 1.2945
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9679 - loss: 0.0866 - val_accuracy: 0.6250 - val_loss: 2.1230
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 54ms/step - accuracy: 0.9665 - loss: 0.1461 - val_accuracy: 0.6970 - val_loss: 1.5405
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9633 - loss: 0.1035 - val_accuracy: 0.7060 - val_loss: 1.5617
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 68ms/step - accuracy: 0.9570 - loss: 0.1321 - val_accuracy: 0.7340 - val_loss: 1.1880
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9904 - loss: 0.0257 - val_accuracy: 0.7390 - val_loss: 1.4553
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.9714 - loss: 0.0827 - val_accuracy: 0.7410 - val_loss: 1.2942
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 71ms/step - accuracy: 0.9851 - loss: 0.0338 - val_accuracy: 0.7450 - val_loss: 1.3994
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.9882 - loss: 0.0417 - val_accuracy: 0.7540 - val_loss: 1.7006
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.9795 - loss: 0.0486 - val_accuracy: 0.7380 - val_loss: 1.7471
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 88ms/step - accuracy: 0.9896 - loss: 0.0363 - val_accuracy: 0.7170 - val_loss: 1.7868
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 53ms/step - accuracy: 0.9904 - loss: 0.0334 - val_accuracy: 0.7450 - val_loss: 1.8975
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 46ms/step - accuracy: 0.9883 - loss: 0.0420 - val_accuracy: 0.7500 - val_loss: 1.6820

# %%
def plot_history(history):

    accuracy = history.history["accuracy"]
    val_accuracy = history.history["val_accuracy"]
    loss = history.history["loss"]
    val_loss = history.history["val_loss"]
    epochs = range(1, len(accuracy) + 1)

    fig, (ax1, ax2) = plt.subplots(nrows=1,ncols=2, constrained_layout=True, figsize=(10,3))

    ax1.plot(epochs, accuracy,label="Training accuracy")
    ax1.plot(epochs, val_accuracy, label="Validation accuracy")
    ax1.set_title("Training and validation accuracy")
    ax1.legend()

    ax2.plot(epochs, loss,  label="Training loss")
    ax2.plot(epochs, val_loss,  label="Validation loss")
    ax2.set_title("Training and validation loss")
    ax2.legend()
    plt.show()

# %% [markdown]
# Let's plot the loss and accuracy of the model over the training and validation data during training:

# %%
plot_history(history)

# %% [markdown]
# Textbook overfitting!
#
# Training accuracy increases, reaching nearly 100%; validation accuracy stalls at about 70%.
#
# Training loss decreases to nearly zero; validation loss reaches its minimum in the first few epochs, then stalls.
#
# Our test accuracy confirms this:

# %%
test_model = tf.keras.models.load_model(MODELS_DIR / "convnet_from_scratch.keras")
test_loss, test_acc = test_model.evaluate(test_dataset, verbose=0)
print(f"Test accuracy: {test_acc:.3f}")
del test_model
# Out:
# Test accuracy: 0.715

# %% [markdown]
# Overfitting is going to be a primary concern because we only have relatively few training samples (2000).
#
# We have seen that *dropout* and *weight decay* (L2 regularisation) can mitigate overfitting.
#
# Let's try a new scheme often used in DL computer vision models: **data augmentation**.
#
# Highly recommended for CW2 if you work with image datasets!

# %% [markdown]
# ----
#
# ## 8.2.5 Data augmentation

# %% [markdown]
# Overfitting is caused by having too few samples.
#
# Trained models are unable to generalize to new data.
#
# Exposing a model to every possible aspect of the data distribution would cure overfitting
# – but we would (generally) need infinite datasets.
#
# But what if we are limited to a small dataset?

# %% [markdown]
# We could *artificially* generate more training data from the existing data.
#
# That is the approach of **data augmentation**.
#
# In this case: apply a random transformations in order to generate credible new images
# (variations on existing ones).

# %% [markdown]
# Then, during training, our model will never see *exactly* the same image twice.
#
# The model is exposed to more aspects of the data (but not different data) and may generalise better.

# %% [markdown]
# **Define a data augmentation stage to add to an image model**
#
# The [official tutorial](https://www.tensorflow.org/guide/keras/preprocessing_layers#image_data_augmentation).

# %%
data_augmentation = tf.keras.Sequential(
    [
        tf.keras.layers.RandomFlip("horizontal"),
        tf.keras.layers.RandomRotation(0.1),
        tf.keras.layers.RandomZoom(0.2),
    ]
)

# %% [markdown]
# **Displaying some randomly augmented training images**

# %%
plt.figure(figsize=(10, 10))
for images, _ in train_dataset.take(1):
    for i in range(9):
        augmented_images = data_augmentation(images)            # each time we run data_augmentation on images
        ax = plt.subplot(3, 3, i + 1)                           # it returns a slightly modified version
        plt.imshow(augmented_images[0].numpy().astype("uint8"))
        plt.axis("off")

# %% [markdown]
# A new model will never see exactly the same image – is this infinite data?
#
# No!
#
# This is *not* generating new information, only *remix* old information, create *variations*.
#
# So we might not completely eradicate overfitting.
#
# We might need other regularisation techniques.
#
# Let's add dropout to the classifier top end.

# %%
tf.keras.backend.clear_session()

inputs = tf.keras.Input(shape=(150, 150, 3))
x = data_augmentation(inputs)
x = tf.keras.layers.Rescaling(1./255)(x)
x = tf.keras.layers.Conv2D(filters=32, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(filters=64, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(filters=128, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.MaxPooling2D(pool_size=2)(x)
x = tf.keras.layers.Conv2D(filters=256, kernel_size=3, activation="relu")(x)
x = tf.keras.layers.Flatten()(x)
x = tf.keras.layers.Dropout(0.5)(x) # ←---------------------------------------- DROPOUT
outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)
model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    loss="binary_crossentropy",
    optimizer="rmsprop",
    metrics=["accuracy"],
)

# %% [markdown]
# Let's train our network using data augmentation and dropout:

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath= str(MODELS_DIR / "convnet_from_scratch_with_augmentation.keras"),
        save_best_only=True,
        monitor="val_loss")
]
history = model.fit(
    train_dataset,
    epochs=100,
    validation_data=validation_dataset,
    callbacks=callbacks)
del model
# Out:
# Epoch 1/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.4951 - loss: 0.6963 - val_accuracy: 0.5120 - val_loss: 0.6923
# Epoch 2/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.5168 - loss: 0.6926 - val_accuracy: 0.6130 - val_loss: 0.6789
# Epoch 3/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.5658 - loss: 0.6799 - val_accuracy: 0.6360 - val_loss: 0.6616
# Epoch 4/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 84ms/step - accuracy: 0.6033 - loss: 0.6675 - val_accuracy: 0.6320 - val_loss: 0.6484
# Epoch 5/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 48ms/step - accuracy: 0.6240 - loss: 0.6447 - val_accuracy: 0.6860 - val_loss: 0.6133
# Epoch 6/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 79ms/step - accuracy: 0.6467 - loss: 0.6250 - val_accuracy: 0.6010 - val_loss: 0.6570
# Epoch 7/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.6569 - loss: 0.6236 - val_accuracy: 0.6920 - val_loss: 0.5819
# Epoch 8/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.6897 - loss: 0.5958 - val_accuracy: 0.6760 - val_loss: 0.5807
# Epoch 9/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 82ms/step - accuracy: 0.6892 - loss: 0.6036 - val_accuracy: 0.6740 - val_loss: 0.5794
# Epoch 10/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 55ms/step - accuracy: 0.6927 - loss: 0.5787 - val_accuracy: 0.7050 - val_loss: 0.5622
# Epoch 11/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.6931 - loss: 0.5802 - val_accuracy: 0.7130 - val_loss: 0.5469
# Epoch 12/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.7297 - loss: 0.5486 - val_accuracy: 0.5380 - val_loss: 1.0942
# Epoch 13/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 51ms/step - accuracy: 0.6925 - loss: 0.6244 - val_accuracy: 0.7300 - val_loss: 0.5082
# Epoch 14/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.7287 - loss: 0.5455 - val_accuracy: 0.7280 - val_loss: 0.5395
# Epoch 15/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 57ms/step - accuracy: 0.7461 - loss: 0.5421 - val_accuracy: 0.7230 - val_loss: 0.5534
# Epoch 16/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.7310 - loss: 0.5303 - val_accuracy: 0.7250 - val_loss: 0.5470
# Epoch 17/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 62ms/step - accuracy: 0.7518 - loss: 0.5329 - val_accuracy: 0.6930 - val_loss: 0.5692
# Epoch 18/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 79ms/step - accuracy: 0.7699 - loss: 0.5012 - val_accuracy: 0.7120 - val_loss: 0.5451
# Epoch 19/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.7478 - loss: 0.5079 - val_accuracy: 0.7680 - val_loss: 0.4873
# Epoch 20/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 55ms/step - accuracy: 0.7662 - loss: 0.4786 - val_accuracy: 0.7520 - val_loss: 0.5182
# Epoch 21/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 73ms/step - accuracy: 0.7795 - loss: 0.4671 - val_accuracy: 0.7600 - val_loss: 0.5074
# Epoch 22/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.7637 - loss: 0.4978 - val_accuracy: 0.7620 - val_loss: 0.5481
# Epoch 23/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.7881 - loss: 0.4606 - val_accuracy: 0.7450 - val_loss: 0.5038
# Epoch 24/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.7933 - loss: 0.4516 - val_accuracy: 0.7850 - val_loss: 0.5215
# Epoch 25/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 63ms/step - accuracy: 0.7729 - loss: 0.4689 - val_accuracy: 0.7710 - val_loss: 0.4960
# Epoch 26/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.7925 - loss: 0.4440 - val_accuracy: 0.7740 - val_loss: 0.4743
# Epoch 27/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8128 - loss: 0.4176 - val_accuracy: 0.7610 - val_loss: 0.6262
# Epoch 28/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 58ms/step - accuracy: 0.8111 - loss: 0.4200 - val_accuracy: 0.6510 - val_loss: 1.1265
# Epoch 29/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.7883 - loss: 0.4734 - val_accuracy: 0.8250 - val_loss: 0.4255
# Epoch 30/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 54ms/step - accuracy: 0.8239 - loss: 0.3984 - val_accuracy: 0.6740 - val_loss: 0.7681
# Epoch 31/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.8131 - loss: 0.4200 - val_accuracy: 0.7650 - val_loss: 0.5141
# Epoch 32/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8195 - loss: 0.4115 - val_accuracy: 0.7980 - val_loss: 0.4213
# Epoch 33/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 55ms/step - accuracy: 0.8297 - loss: 0.3816 - val_accuracy: 0.8110 - val_loss: 0.4332
# Epoch 34/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 74ms/step - accuracy: 0.8447 - loss: 0.3581 - val_accuracy: 0.8250 - val_loss: 0.4345
# Epoch 35/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8345 - loss: 0.3787 - val_accuracy: 0.7690 - val_loss: 0.4707
# Epoch 36/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8343 - loss: 0.3630 - val_accuracy: 0.8020 - val_loss: 0.4802
# Epoch 37/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 69ms/step - accuracy: 0.8381 - loss: 0.3780 - val_accuracy: 0.8290 - val_loss: 0.3935
# Epoch 38/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 60ms/step - accuracy: 0.8456 - loss: 0.3553 - val_accuracy: 0.8170 - val_loss: 0.4508
# Epoch 39/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.8631 - loss: 0.3164 - val_accuracy: 0.8070 - val_loss: 0.4555
# Epoch 40/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8463 - loss: 0.3412 - val_accuracy: 0.8060 - val_loss: 0.4983
# Epoch 41/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 66ms/step - accuracy: 0.8632 - loss: 0.3109 - val_accuracy: 0.8170 - val_loss: 0.4455
# Epoch 42/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 56ms/step - accuracy: 0.8572 - loss: 0.3391 - val_accuracy: 0.8130 - val_loss: 0.4252
# Epoch 43/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8511 - loss: 0.3236 - val_accuracy: 0.8010 - val_loss: 0.5380
# Epoch 44/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 85ms/step - accuracy: 0.8691 - loss: 0.3129 - val_accuracy: 0.8070 - val_loss: 0.4245
# Epoch 45/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.8534 - loss: 0.2971 - val_accuracy: 0.7420 - val_loss: 0.9581
# Epoch 46/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8646 - loss: 0.3372 - val_accuracy: 0.8170 - val_loss: 0.4272
# Epoch 47/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8848 - loss: 0.2761 - val_accuracy: 0.7510 - val_loss: 0.6502
# Epoch 48/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 53ms/step - accuracy: 0.8743 - loss: 0.3093 - val_accuracy: 0.8230 - val_loss: 0.4742
# Epoch 49/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.8794 - loss: 0.2918 - val_accuracy: 0.8160 - val_loss: 0.5435
# Epoch 50/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.8759 - loss: 0.2758 - val_accuracy: 0.8280 - val_loss: 0.5960
# Epoch 51/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 69ms/step - accuracy: 0.8899 - loss: 0.2800 - val_accuracy: 0.6890 - val_loss: 1.4143
# Epoch 52/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.8703 - loss: 0.3220 - val_accuracy: 0.8210 - val_loss: 0.4808
# Epoch 53/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.8889 - loss: 0.2693 - val_accuracy: 0.8040 - val_loss: 0.5561
# Epoch 54/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 90ms/step - accuracy: 0.8940 - loss: 0.2610 - val_accuracy: 0.8170 - val_loss: 0.6423
# Epoch 55/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8979 - loss: 0.2558 - val_accuracy: 0.8230 - val_loss: 0.5105
# Epoch 56/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8870 - loss: 0.3071 - val_accuracy: 0.8200 - val_loss: 0.5056
# Epoch 57/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 72ms/step - accuracy: 0.8995 - loss: 0.2323 - val_accuracy: 0.8060 - val_loss: 0.6834
# Epoch 58/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.9137 - loss: 0.2323 - val_accuracy: 0.8160 - val_loss: 0.5540
# Epoch 59/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.9198 - loss: 0.2058 - val_accuracy: 0.8360 - val_loss: 0.5287
# Epoch 60/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9047 - loss: 0.2398 - val_accuracy: 0.8430 - val_loss: 0.5424
# Epoch 61/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.8903 - loss: 0.2709 - val_accuracy: 0.8320 - val_loss: 0.5399
# Epoch 62/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9176 - loss: 0.2109 - val_accuracy: 0.8270 - val_loss: 0.5461
# Epoch 63/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9110 - loss: 0.2185 - val_accuracy: 0.8180 - val_loss: 0.5027
# Epoch 64/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.9127 - loss: 0.2326 - val_accuracy: 0.8190 - val_loss: 0.7116
# Epoch 65/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 49ms/step - accuracy: 0.9159 - loss: 0.2189 - val_accuracy: 0.8400 - val_loss: 0.5679
# Epoch 66/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 64ms/step - accuracy: 0.9182 - loss: 0.2146 - val_accuracy: 0.8170 - val_loss: 0.4821
# Epoch 67/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 65ms/step - accuracy: 0.9139 - loss: 0.2110 - val_accuracy: 0.8090 - val_loss: 0.6544
# Epoch 68/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9352 - loss: 0.1934 - val_accuracy: 0.8420 - val_loss: 0.5507
# Epoch 69/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 50ms/step - accuracy: 0.9405 - loss: 0.1624 - val_accuracy: 0.8250 - val_loss: 0.5736
# Epoch 70/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 59ms/step - accuracy: 0.9251 - loss: 0.1949 - val_accuracy: 0.8280 - val_loss: 0.6137
# Epoch 71/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.9290 - loss: 0.1755 - val_accuracy: 0.8390 - val_loss: 0.6115
# Epoch 72/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 67ms/step - accuracy: 0.9161 - loss: 0.2091 - val_accuracy: 0.8250 - val_loss: 0.5839
# Epoch 73/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 98ms/step - accuracy: 0.9259 - loss: 0.1850 - val_accuracy: 0.7410 - val_loss: 1.0929
# Epoch 74/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 49ms/step - accuracy: 0.9134 - loss: 0.1989 - val_accuracy: 0.7930 - val_loss: 0.7664
# Epoch 75/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9216 - loss: 0.1948 - val_accuracy: 0.8360 - val_loss: 0.6158
# Epoch 76/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 56ms/step - accuracy: 0.9169 - loss: 0.2262 - val_accuracy: 0.8350 - val_loss: 0.6397
# Epoch 77/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 86ms/step - accuracy: 0.9243 - loss: 0.1848 - val_accuracy: 0.8420 - val_loss: 0.5244
# Epoch 78/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9414 - loss: 0.1536 - val_accuracy: 0.8300 - val_loss: 0.6462
# Epoch 79/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9167 - loss: 0.2079 - val_accuracy: 0.8410 - val_loss: 0.5949
# Epoch 80/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 77ms/step - accuracy: 0.9339 - loss: 0.1746 - val_accuracy: 0.8360 - val_loss: 0.6083
# Epoch 81/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.9307 - loss: 0.1602 - val_accuracy: 0.7780 - val_loss: 1.2897
# Epoch 82/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9313 - loss: 0.1666 - val_accuracy: 0.8360 - val_loss: 0.6867
# Epoch 83/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9428 - loss: 0.1588 - val_accuracy: 0.8430 - val_loss: 0.5044
# Epoch 84/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 5s 78ms/step - accuracy: 0.9221 - loss: 0.2003 - val_accuracy: 0.8360 - val_loss: 0.5406
# Epoch 85/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 56ms/step - accuracy: 0.9431 - loss: 0.1463 - val_accuracy: 0.8340 - val_loss: 0.5326
# Epoch 86/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 47ms/step - accuracy: 0.9500 - loss: 0.1323 - val_accuracy: 0.8350 - val_loss: 0.7079
# Epoch 87/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 80ms/step - accuracy: 0.9349 - loss: 0.1928 - val_accuracy: 0.8160 - val_loss: 0.5630
# Epoch 88/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 55ms/step - accuracy: 0.9343 - loss: 0.1573 - val_accuracy: 0.8220 - val_loss: 0.8525
# Epoch 89/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 49ms/step - accuracy: 0.9376 - loss: 0.1658 - val_accuracy: 0.8230 - val_loss: 0.7164
# Epoch 90/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 70ms/step - accuracy: 0.9332 - loss: 0.1740 - val_accuracy: 0.8510 - val_loss: 0.5836
# Epoch 91/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 48ms/step - accuracy: 0.9337 - loss: 0.1725 - val_accuracy: 0.8450 - val_loss: 0.7617
# Epoch 92/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 48ms/step - accuracy: 0.9435 - loss: 0.1483 - val_accuracy: 0.8380 - val_loss: 0.6934
# Epoch 93/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9554 - loss: 0.1329 - val_accuracy: 0.8410 - val_loss: 0.6893
# Epoch 94/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 6s 64ms/step - accuracy: 0.9621 - loss: 0.1121 - val_accuracy: 0.8550 - val_loss: 0.6297
# Epoch 95/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9525 - loss: 0.1502 - val_accuracy: 0.8310 - val_loss: 0.7697
# Epoch 96/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9476 - loss: 0.1621 - val_accuracy: 0.8180 - val_loss: 0.7748
# Epoch 97/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 100ms/step - accuracy: 0.9412 - loss: 0.1582 - val_accuracy: 0.8510 - val_loss: 0.6669
# Epoch 98/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 48ms/step - accuracy: 0.9366 - loss: 0.1717 - val_accuracy: 0.8340 - val_loss: 0.6851
# Epoch 99/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 7s 75ms/step - accuracy: 0.9512 - loss: 0.1338 - val_accuracy: 0.8360 - val_loss: 0.5647
# Epoch 100/100
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 3s 55ms/step - accuracy: 0.9487 - loss: 0.1630 - val_accuracy: 0.8370 - val_loss: 0.6527

# %%
plot_history(history)

# %%
test_model = tf.keras.models.load_model(MODELS_DIR / "convnet_from_scratch_with_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset, verbose=0)
print(f"Test accuracy: {test_acc:.3f}")
del test_model
# Out:
# Test accuracy: 0.802

# %% [markdown]
# Other regularisation techniques and hyper-parameter tuning can push the accuracy higher by a few percents.
#
# But the ultimate potential in training our own model from scratch is limited because of the size of our training set.
#
# The next section shows how models that have been trained on different, larger, datasets, can be applied to the small-data problem.

# %% [markdown]
# ----
#
# ## 8.3 Leveraging a pretrained model

# %% [markdown]
# A pretrained network is simply a network that has been trained on a large dataset – typically, a large-scale image classification task – and saved for public use.
#
# The pre-trained model, if it has been trained on a large and sufficiently general dataset, **will have learned the spatial feature hierarchy of real-world objects** (edges and corners, simple shapes, compound shapes).

# %% [markdown]
# Such a pretrained model would prove useful for many different computer vision problems – even for completely different classes from those of the original task.
#
# For example, train a network on a dataset where the classes are mostly animals and everyday objects then, apply this trained network to identifying furniture.
#
# It would not work as well as if you had a lot of furniture data to train on (same distribution), but it would be better than starting from scratch!

# %% [markdown]
# The ability of DL models to solve new, unseen problems distinguishes DL from older, shallow learning techniques.
#
# It also makes DL very effective for small-data problems.

# %% [markdown]
# Let's consider a large convnet trained on the ImageNet dataset.
#
# (1.4 million labeled images and 1000 different classes)
#
# ImageNet contains many animal classes, including different types of cats and dogs.
#
# We can expect it to perform very well on our Dog vs. Cat problem.

# %% [markdown]
# `tensorflow.keras` has several pretrained models - they have all been trained on ImageNet :
#
# * Xception
# * InceptionV3
# * ResNet50
# * VGG16
# * VGG19
# * MobileNet
#
# Find them all [here](https://www.tensorflow.org/api_docs/python/tf/keras/applications).

# %% [markdown]
# We will use the VGG16 architecture.
#
# It is a simple and widely used convnet architecture for ImageNet.
#
# VGG16 is not necessarily the lightest and best pretrained model, but the architecture is similar to our previous convnets.

# %% [markdown]
# There are two main ways to deploy a pre-trained network:
#
#  - **feature extraction**
#  - **fine-tuning**

# %% [markdown]
# ----
#
# ## 8.3.1 Feature extraction with a pretrained model

# %% [markdown]
# Feature extraction means using (extracting) the **learned representations** (features) of trained networks to find relevant features in new datasets.
#
# Convnets are built in two parts:
# - a *convolutional base* of pooling and conv layers;
# - densely-connected classifier.
#
# The **base** weights and biases are *frozen* – held fixed, no gradient updates – and the original classifier is replaced with a new classifier that is more appropriate to the task in hand.

# %% [markdown]
# As a result:
#
#   - the trained conv base *extracts features*;
#   - the new classifier is trained to *interpret these features in terms of the new classes*.

# %% [markdown]
# Why only reuse the convolutional base? Why not use the densely-connected classifier as well?
#
# Because representations learned by the convolutional base are likely to be  **generic concepts** (edges, corners, textures, etc) – that will apply to many real-world images.
#
# Those learned by the classifier are *specific* and *non-spatial* (tailored for the original training set).

# %% [markdown]
# The generality (and therefore reusability) of the representations extracted by specific convolution layers depends on the depth of the layer in the model:
# - early, lower, layers extract **local, highly generic feature** (such as visual edges, colours, textures);
# - higher layers extract **more abstract concepts** (such as 'cat ear' or 'dog eye');
# - use the lower layers only, and not the entire base, for datasets that differ markedly from the original dataset of the trained model.

# %% [markdown]
# The constructor takes three arguments:
#
# * `weights`: either `none`, `imagenet` or a path to a weights file;
# * `include_top`: to include the three layer densely-connected 1000 class classifier;
# * `input_shape`: shape of the input image tensor.

# %%
tf.keras.backend.clear_session()

conv_base = tf.keras.applications.VGG16(
    weights='imagenet',
    include_top=False,
    input_shape=(150, 150, 3)
)

# %% [markdown]
# Here's the detail of the architecture of the VGG16 convolutional base: it's very similar to the simple convnets that you are already familiar with...

# %%
conv_base.summary()
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, 150, 150, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, 150, 150, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 150, 150, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 75, 75, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 75, 75, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, 75, 75, 128)         │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, 37, 37, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, 37, 37, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, 37, 37, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, 37, 37, 256)         │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, 18, 18, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, 18, 18, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, 18, 18, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, 18, 18, 512)         │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, 9, 9, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, 9, 9, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, 9, 9, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, 9, 9, 512)           │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, 4, 4, 512)           │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 14,714,688 (56.13 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ##### Note
#
# You can see that our densely-connected classifier must accept the `(4, 4, 512)` output of the final feature map.

# %% [markdown]
# ### Two options
#
# 1. Extract *then* train
# 2. Freeze *and* train

# %% [markdown]
# #### 1. Extract *then* train

# %% [markdown]
#   - run the convolutional base over Dogs vs Cats and save the outputs as a NumPy array;
#   - use the processed features as input to a standalone densely-connected classifier.
#
# This is very fast because it only requires running the convolutional base once for every input image (the convolutional base is by far the most expensive part of the pipeline).
#
# But this technique would prohibit data augmentation.

# %% [markdown]
# **Note**
#
# This is similar to training a classifier on a dataset of *4 x 4 'images' each with 512 channels* (!).

# %% [markdown]
# #### 2. Freeze *and* train

# %% [markdown]
#   - **freeze** (= prevent training) the whole `conv_base`;
#   - add `Dense` layers on top of `conv_base`;
#   - train the whole thing end-to-end on the input data.
#
# Every input image is going through the convolutional base every time it is seen by the model – we can use data augmentation.
#
# But this technique is more computationally intensive.

# %% [markdown]
# ---
#
# ### 1. Fast feature extraction without data augmentation

# %% [markdown]
# Let's look at option 1 (recording the outputs of `conv_base` on our data and using these outputs as inputs to a new model).

# %% [markdown]
# **Extracting the VGG16 features and corresponding labels**

# %%
def get_features_and_labels(dataset):
    all_features = []
    all_labels = []
    for images, labels in dataset: # ← LOOP THROUGH THE ENTIRE DATASET
        preprocessed_images = tf.keras.applications.vgg16.preprocess_input(images) # preprocess the images
        features = conv_base.predict(preprocessed_images, verbose=0)               # run the images through the model
        all_features.append(features)
        all_labels.append(labels)
    return np.concatenate(all_features), np.concatenate(all_labels)

# our feature datasets
train_features, train_labels = get_features_and_labels(train_dataset)
val_features, val_labels = get_features_and_labels(validation_dataset)
test_features, test_labels = get_features_and_labels(test_dataset)

# %%
train_features.shape # the shape of the current features: `(samples, 4, 4, 512)`
# Out:
# (2000, 4, 4, 512)

# %% [markdown]
# **Defining and training the densely connected classifier**

# %%
# ↓ DEFINITION OF OUR NEW MODEL ---------------------------
inputs = tf.keras.Input(shape=(4, 4, 512))
x = tf.keras.layers.Flatten()(inputs)
x = tf.keras.layers.Dense(256)(x)
x = tf.keras.layers.Dropout(0.5)(x) # quite a bit of dropout
outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)
# ↑ -------------------------------------------------------
model = tf.keras.Model(inputs, outputs)                     # finalise model by giving the inputs & outputs


model.compile(
    loss="binary_crossentropy",
    optimizer="rmsprop",
    metrics=["accuracy"]
)

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
      filepath= str(MODELS_DIR / "feature_extraction.keras"),
      save_best_only=True,
      monitor="val_loss")
]

history = model.fit(
    train_features, train_labels,
    epochs=20,
    validation_data=(val_features, val_labels),
    callbacks=callbacks)

del model
# Out:
# Epoch 1/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 4s 32ms/step - accuracy: 0.8543 - loss: 40.9221 - val_accuracy: 0.9490 - val_loss: 4.1287
# Epoch 2/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9740 - loss: 2.7088 - val_accuracy: 0.9680 - val_loss: 3.4592
# Epoch 3/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9858 - loss: 1.7903 - val_accuracy: 0.9660 - val_loss: 3.7621
# Epoch 4/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9865 - loss: 0.9050 - val_accuracy: 0.9650 - val_loss: 5.8091
# Epoch 5/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9832 - loss: 1.4554 - val_accuracy: 0.9680 - val_loss: 4.0566
# Epoch 6/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9951 - loss: 0.3253 - val_accuracy: 0.9360 - val_loss: 12.9070
# Epoch 7/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9924 - loss: 0.5484 - val_accuracy: 0.9630 - val_loss: 5.5824
# Epoch 8/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9930 - loss: 1.0090 - val_accuracy: 0.9630 - val_loss: 6.0895
# Epoch 9/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9952 - loss: 0.3770 - val_accuracy: 0.9610 - val_loss: 7.4022
# Epoch 10/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9918 - loss: 0.7820 - val_accuracy: 0.9660 - val_loss: 5.8827
# Epoch 11/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9956 - loss: 0.2072 - val_accuracy: 0.9680 - val_loss: 5.5494
# Epoch 12/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9961 - loss: 0.2364 - val_accuracy: 0.9670 - val_loss: 6.1418
# Epoch 13/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9965 - loss: 0.1795 - val_accuracy: 0.9700 - val_loss: 5.2982
# Epoch 14/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9982 - loss: 0.0818 - val_accuracy: 0.9600 - val_loss: 6.8083
# Epoch 15/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9953 - loss: 0.3878 - val_accuracy: 0.9620 - val_loss: 7.9389
# Epoch 16/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9943 - loss: 0.2475 - val_accuracy: 0.9710 - val_loss: 4.3724
# Epoch 17/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9980 - loss: 0.1860 - val_accuracy: 0.9690 - val_loss: 4.7118
# Epoch 18/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9985 - loss: 0.1421 - val_accuracy: 0.9660 - val_loss: 5.2652
# Epoch 19/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9979 - loss: 0.0536 - val_accuracy: 0.9580 - val_loss: 9.1786
# Epoch 20/20
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9970 - loss: 0.3277 - val_accuracy: 0.9690 - val_loss: 5.2170

# %% [markdown]
# Training is very fast, less than 1 sec/epoch, since there are only two `Dense` layers.
#
# Inspect training loss and accuracy:

# %%
plot_history(history)

# %%
test_model = tf.keras.models.load_model(MODELS_DIR / "feature_extraction.keras")
test_loss, test_acc = test_model.evaluate(test_features, test_labels, verbose=0)
print(f"Test accuracy: {test_acc:.3f}")
del test_model
# Out:
# Test accuracy: 0.965

# %% [markdown]
# We attain about 96% validation accuracy.
#
# Much better than our small model trained from scratch!
#
# But the plots also indicate overfitting despite 50% dropout.

# %% [markdown]
# However, generator driven data augmentation is impossible with option 1.
#
# Also, data augmentation is essential for preventing overfitting with small image datasets.

# %% [markdown]
# ---
#
# ### 2. Feature extraction together with data augmentation

# %% [markdown]
# So let's now consider option 2 (freeze and train).

# %% [markdown]
# A layer is **frozen** if its weights cannot be updated during training.
#
# The model or layer `trainable` attribute is set to `False`.
#
# Freezing must take place before compilation.

# %% [markdown]
# **Note**
#
# Why freezing? The `Dense` layers on top are randomly initialized. The very large weight updates happening at the beginning of training would be propagated through the network, effectively *destroying*/*damaging* the previously learned representations of the conv base.

# %% [markdown]
# <!-- <img style="height:700px" src="images/chollet.swapping_fc_classifier.png"> -->
# <img style="height:700px" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/chollet.swapping_fc_classifier.png?raw=true">
#
# <small>DLWP, p.226</small>

# %% [markdown]
# **Instantiating and freezing the VGG16 convolutional base**

# %%
tf.keras.backend.clear_session()

conv_base  = tf.keras.applications.vgg16.VGG16(
    weights="imagenet",
    include_top=False       # ← NO CLASSIFIER, we train our own
)
conv_base.trainable = False # ← FREEZE THE BASE

# %% [markdown]
# **Note**
#
# VGG16 has 13 conv layers and each layer has a main weight tensor ($w$) and a bias tensor ($b$).
#
# The dense classifier has two trainable layers – that's four more tensors of trainable parameters.
#
# 26 tensors of trainable parameters before freezing.
#
# 4 tensors after freezing.

# %% [markdown]
# **Printing the list of trainable weights before and after freezing**

# %%
conv_base.trainable = True
print("Number of trainable weights before freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# Number of trainable weights before freezing the conv base: 26

# %%
conv_base.trainable = False
print("Number of trainable weights after freezing the conv base:", len(conv_base.trainable_weights))
# Out:
# Number of trainable weights after freezing the conv base: 0

# %% [markdown]
# **Adding a data augmentation stage and a classifier to the convolutional base**

# %%
# ↓ DEFINITION OF OUR NEW MODEL ---------------------------
inputs = tf.keras.Input(shape=(150, 150, 3))
#   ↓ our processed inputs
x = data_augmentation(inputs)
#   ↓ VGG16-specific processing (scales inputs to appropriate range)
x = tf.keras.applications.vgg16.preprocess_input(x)
#   ↓ OUR FROZEN VGG BASE
x = conv_base(x)                                            # ← `tf.keras` presents a
#   ↓ the rest of our net                                   #   common interface for models and
x = tf.keras.layers.Flatten()(x)                            #   layers – models can be clicked
x = tf.keras.layers.Dense(256)(x)                           #   into place as if they were layers!
x = tf.keras.layers.Dropout(0.5)(x)
outputs = tf.keras.layers.Dense(1, activation="sigmoid")(x)
# ↑ -------------------------------------------------------
model = tf.keras.Model(inputs, outputs)                     #   finalise model by giving the inputs & outputs

model.compile(
    loss="binary_crossentropy",
    optimizer="rmsprop",
    metrics=["accuracy"]
)

# %%
model.summary() # 16 million params (but only 2 million trainable ones)!
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)              ┃ Output Shape           ┃        Param # ┃ Connected to           ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1             │ (None, 150, 150, 3)    │              0 │ -                      │
# │ (InputLayer)              │                        │                │                        │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ sequential (Sequential)   │ (None, 150, 150, 3)    │              0 │ input_layer_1[0][0]    │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item (GetItem)        │ (None, 150, 150)       │              0 │ sequential[1][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_1 (GetItem)      │ (None, 150, 150)       │              0 │ sequential[1][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ get_item_2 (GetItem)      │ (None, 150, 150)       │              0 │ sequential[1][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ stack (Stack)             │ (None, 150, 150, 3)    │              0 │ get_item[0][0],        │
# │                           │                        │                │ get_item_1[0][0],      │
# │                           │                        │                │ get_item_2[0][0]       │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ add (Add)                 │ (None, 150, 150, 3)    │              0 │ stack[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ vgg16 (Functional)        │ (None, 4, 4, 512)      │     14,714,688 │ add[0][0]              │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ flatten (Flatten)         │ (None, 8192)           │              0 │ vgg16[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense (Dense)             │ (None, 256)            │      2,097,408 │ flatten[0][0]          │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dropout (Dropout)         │ (None, 256)            │              0 │ dense[0][0]            │
# ├───────────────────────────┼────────────────────────┼────────────────┼────────────────────────┤
# │ dense_1 (Dense)           │ (None, 1)              │            257 │ dropout[0][0]          │
# └───────────────────────────┴────────────────────────┴────────────────┴────────────────────────┘
#  Total params: 16,812,353 (64.13 MB)
#  Trainable params: 2,097,665 (8.00 MB)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# 16.8 million parameters in the convolutional base and 2 million dense classifier parameters.

# %%
callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath= str(MODELS_DIR / "feature_extraction_with_data_augmentation.keras"),
        save_best_only=True,
        monitor="val_loss"
    )
]
history = model.fit(
    train_dataset,
    epochs=50,
    validation_data=validation_dataset,
    callbacks=callbacks
)
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 16s 192ms/step - accuracy: 0.8164 - loss: 31.1432 - val_accuracy: 0.9380 - val_loss: 7.1601
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 14s 121ms/step - accuracy: 0.9326 - loss: 6.5977 - val_accuracy: 0.9470 - val_loss: 7.4274
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.9281 - loss: 6.3931 - val_accuracy: 0.9620 - val_loss: 4.7306
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - accuracy: 0.9356 - loss: 7.2181 - val_accuracy: 0.9600 - val_loss: 3.8469
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - accuracy: 0.9480 - loss: 4.0395 - val_accuracy: 0.9700 - val_loss: 3.9211
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.9491 - loss: 5.5594 - val_accuracy: 0.9700 - val_loss: 3.3316
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9485 - loss: 4.4050 - val_accuracy: 0.9630 - val_loss: 3.4376
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9632 - loss: 2.8396 - val_accuracy: 0.9670 - val_loss: 3.3603
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9594 - loss: 3.2258 - val_accuracy: 0.9580 - val_loss: 4.5255
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 126ms/step - accuracy: 0.9655 - loss: 2.8182 - val_accuracy: 0.9770 - val_loss: 1.7312
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9588 - loss: 3.7333 - val_accuracy: 0.9720 - val_loss: 1.7882
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9664 - loss: 1.6265 - val_accuracy: 0.9720 - val_loss: 2.5086
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9718 - loss: 1.2446 - val_accuracy: 0.9740 - val_loss: 2.0757
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 146ms/step - accuracy: 0.9671 - loss: 2.3827 - val_accuracy: 0.9720 - val_loss: 1.7001
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 133ms/step - accuracy: 0.9744 - loss: 1.6991 - val_accuracy: 0.9750 - val_loss: 1.2711
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 121ms/step - accuracy: 0.9748 - loss: 0.8047 - val_accuracy: 0.9760 - val_loss: 1.3127
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9671 - loss: 1.6344 - val_accuracy: 0.9750 - val_loss: 1.5170
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 119ms/step - accuracy: 0.9714 - loss: 1.3317 - val_accuracy: 0.9640 - val_loss: 1.9859
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - accuracy: 0.9817 - loss: 0.7494 - val_accuracy: 0.9640 - val_loss: 1.4926
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9656 - loss: 1.0125 - val_accuracy: 0.9720 - val_loss: 1.6314
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9713 - loss: 1.1965 - val_accuracy: 0.9730 - val_loss: 1.5672
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9771 - loss: 0.6260 - val_accuracy: 0.9660 - val_loss: 1.6403
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9826 - loss: 0.4159 - val_accuracy: 0.9580 - val_loss: 2.3486
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9701 - loss: 0.8572 - val_accuracy: 0.9660 - val_loss: 1.9379
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9683 - loss: 0.9589 - val_accuracy: 0.9600 - val_loss: 1.8378
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 129ms/step - accuracy: 0.9659 - loss: 0.7633 - val_accuracy: 0.9700 - val_loss: 1.1085
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9793 - loss: 0.6813 - val_accuracy: 0.9730 - val_loss: 1.1309
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9772 - loss: 0.5279 - val_accuracy: 0.9680 - val_loss: 1.2604
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9719 - loss: 0.7570 - val_accuracy: 0.9710 - val_loss: 1.2102
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9707 - loss: 0.6467 - val_accuracy: 0.9690 - val_loss: 1.4286
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9774 - loss: 0.5697 - val_accuracy: 0.9660 - val_loss: 1.2153
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 126ms/step - accuracy: 0.9716 - loss: 0.6612 - val_accuracy: 0.9770 - val_loss: 0.9244
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9733 - loss: 0.3887 - val_accuracy: 0.9660 - val_loss: 1.0984
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9668 - loss: 0.7705 - val_accuracy: 0.9690 - val_loss: 1.2637
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9758 - loss: 0.5227 - val_accuracy: 0.9710 - val_loss: 0.9702
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9801 - loss: 0.3501 - val_accuracy: 0.9580 - val_loss: 1.6355
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 128ms/step - accuracy: 0.9789 - loss: 0.3835 - val_accuracy: 0.9740 - val_loss: 0.8543
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9823 - loss: 0.5160 - val_accuracy: 0.9760 - val_loss: 1.1336
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9657 - loss: 0.5271 - val_accuracy: 0.9570 - val_loss: 1.6596
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9838 - loss: 0.3165 - val_accuracy: 0.9760 - val_loss: 0.9919
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 130ms/step - accuracy: 0.9681 - loss: 0.7067 - val_accuracy: 0.9790 - val_loss: 0.7572
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9789 - loss: 0.3452 - val_accuracy: 0.9660 - val_loss: 1.2725
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9708 - loss: 0.5697 - val_accuracy: 0.9770 - val_loss: 1.1016
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9721 - loss: 0.5235 - val_accuracy: 0.9760 - val_loss: 1.1168
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9749 - loss: 0.4249 - val_accuracy: 0.9730 - val_loss: 1.0749
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.9820 - loss: 0.2855 - val_accuracy: 0.9760 - val_loss: 0.9771
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9792 - loss: 0.4183 - val_accuracy: 0.9720 - val_loss: 1.3455
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9726 - loss: 0.6672 - val_accuracy: 0.9650 - val_loss: 1.6522
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9764 - loss: 0.5075 - val_accuracy: 0.9680 - val_loss: 1.3289
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9839 - loss: 0.2389 - val_accuracy: 0.9790 - val_loss: 1.2309

# %% [markdown]
# Inspect training: no overfitting – data augmentation has worked!

# %%
plot_history(history)

# %%
test_model = tf.keras.models.load_model(MODELS_DIR / "feature_extraction_with_data_augmentation.keras")
test_loss, test_acc = test_model.evaluate(test_dataset, verbose=0)
print(f"Test accuracy: {test_acc:.3f}")
del test_model
# Out:
# Test accuracy: 0.964

# %% [markdown]
# We reach a validation accuracy of about 96-7%, a bit better than option 1 (extract, then train) and again better than the small convnet trained from scratch.
#
# But there is a final trick up the pretrained sleeve.

# %% [markdown]
# ----
#
# ## 8.3.2 Fine-tuning

# %% [markdown]
# Another widely used technique: unfreezing a few of the top layers of a frozen model base.
#
# *Fine-tuning* adjusts the more abstract representations of the pretrained model in order to make them more relevant for the problem at hand.

# %% [markdown]
# <!-- <img style="height:700px" src="images/chollet.vgg16_fine_tuning.png"> -->
# <img style="height:700px" src="https://github.com/jchwenger/AI/blob/main/5-DL-for-computer-vision/images/chollet.vgg16_fine_tuning.png?raw=true">
#
# <small>DLWP, p.234</small>

# %% [markdown]
# #### Note

# %% [markdown]
# **One should only possible to fine-tune the top layers of the convolutional base *once the classifier on
# top has already been trained*.**
#
# Otherwise the error signal propagating back through the network would be too large and the representations previously learned by the unfrozen conv layers would be destroyed.

# %% [markdown]
# ### Fine-tuning workflow

# %% [markdown]
# 1. Add the custom classifier on top of the pretrained base
# 2. Freeze the base
# 3. Train the custom classifier
# 4. Unfreeze some base layers
# 5. Jointly train these layers and the custom classifier
#
# We have already completed the first 3 steps, let's proceed with step 4.

# %%
conv_base.summary() # 14 million params, none trainable ones!
# Out:
# Model: "vgg16"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer (InputLayer)             │ (None, None, None, 3)       │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv1 (Conv2D)                │ (None, None, None, 64)      │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, None, None, 64)      │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, None, None, 64)      │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, None, None, 128)     │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv2 (Conv2D)                │ (None, None, None, 128)     │         147,584 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_pool (MaxPooling2D)           │ (None, None, None, 128)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv1 (Conv2D)                │ (None, None, None, 256)     │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv2 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_conv3 (Conv2D)                │ (None, None, None, 256)     │         590,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block3_pool (MaxPooling2D)           │ (None, None, None, 256)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv1 (Conv2D)                │ (None, None, None, 512)     │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block4_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv1 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv2 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_conv3 (Conv2D)                │ (None, None, None, 512)     │       2,359,808 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block5_pool (MaxPooling2D)           │ (None, None, None, 512)     │               0 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 14,714,688 (56.13 MB)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 14,714,688 (56.13 MB)

# %% [markdown]
# #### Note

# %% [markdown]
# Why not fine-tune more layers? Why not fine-tune the entire convolutional base?
#
# Earlier conv base layers encode **generic features** (edges, textures) whilst higher layers encode more **specialised features**.
#
# The generic features are expected to be present in any real-world image.
#
# It is more useful to fine-tune the more specialized features.

# %% [markdown]
# #### Note

# %% [markdown]
# The convolutional base has 14.7M parameters – a large model with a very real chance of overfitting.
#
# That is another reason not to fine-tune the entire base.

# %% [markdown]
# #### Reloading & finetuning

# %%
# In case you are doing this in installments, reload the feature extraction model
model = tf.keras.models.load_model(MODELS_DIR / "feature_extraction_with_data_augmentation.keras")

# %% [markdown]
# Fine-tune the last 3 convolutional layers (`-4` because there's a `MaxPooling` one in the list).

# %%
conv_base.trainable = True
for layer in conv_base.layers[:-4]: # freeze all until the fourth from the last
    layer.trainable = False

# %% [markdown]
# All layers up to `block4_pool` will be frozen.
#
# `block5_conv1`, `block5_conv2` and `block5_conv3` will be trainable.

# %%
model.compile(
    loss="binary_crossentropy",         # ↓ SMALL LEARNING RATE – We should limit the magnitude of modifications to
    optimizer=tf.keras.optimizers.RMSprop(learning_rate=1e-5), # the representations of the unfrozen layers. Large
    metrics=["accuracy"],                                      # updates may damage these representations...
)

callbacks = [
    tf.keras.callbacks.ModelCheckpoint(
        filepath= str(MODELS_DIR / "fine_tuning.keras"),
        save_best_only=True,
        monitor="val_loss"
    )
]
history = model.fit(
    train_dataset,
    epochs=30,
    validation_data=validation_dataset,
    callbacks=callbacks
)
del model
# Out:
# Epoch 1/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 135ms/step - accuracy: 0.9859 - loss: 0.2310 - val_accuracy: 0.9800 - val_loss: 0.7623
# Epoch 2/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9766 - loss: 0.4065 - val_accuracy: 0.9790 - val_loss: 0.7662
# Epoch 3/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9825 - loss: 0.2869 - val_accuracy: 0.9770 - val_loss: 0.7768
# Epoch 4/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9779 - loss: 0.2606 - val_accuracy: 0.9750 - val_loss: 0.7963
# Epoch 5/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9839 - loss: 0.1518 - val_accuracy: 0.9760 - val_loss: 0.7888
# Epoch 6/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9861 - loss: 0.1658 - val_accuracy: 0.9760 - val_loss: 0.7876
# Epoch 7/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9697 - loss: 0.4524 - val_accuracy: 0.9760 - val_loss: 0.7784
# Epoch 8/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 124ms/step - accuracy: 0.9869 - loss: 0.2602 - val_accuracy: 0.9760 - val_loss: 0.7888
# Epoch 9/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9853 - loss: 0.3281 - val_accuracy: 0.9760 - val_loss: 0.7898
# Epoch 10/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 123ms/step - accuracy: 0.9801 - loss: 0.3063 - val_accuracy: 0.9760 - val_loss: 0.7867
# Epoch 11/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 124ms/step - accuracy: 0.9761 - loss: 0.3780 - val_accuracy: 0.9760 - val_loss: 0.7850
# Epoch 12/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9814 - loss: 0.4074 - val_accuracy: 0.9770 - val_loss: 0.7654
# Epoch 13/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9815 - loss: 0.3220 - val_accuracy: 0.9770 - val_loss: 0.7703
# Epoch 14/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9849 - loss: 0.2881 - val_accuracy: 0.9770 - val_loss: 0.7708
# Epoch 15/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 120ms/step - accuracy: 0.9838 - loss: 0.2460 - val_accuracy: 0.9760 - val_loss: 0.7706
# Epoch 16/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9800 - loss: 0.3616 - val_accuracy: 0.9770 - val_loss: 0.7666
# Epoch 17/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 122ms/step - accuracy: 0.9784 - loss: 0.2078 - val_accuracy: 0.9770 - val_loss: 0.7625
# Epoch 18/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 130ms/step - accuracy: 0.9836 - loss: 0.3935 - val_accuracy: 0.9770 - val_loss: 0.7621
# Epoch 19/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 120ms/step - accuracy: 0.9816 - loss: 0.2852 - val_accuracy: 0.9760 - val_loss: 0.7712
# Epoch 20/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9893 - loss: 0.2114 - val_accuracy: 0.9750 - val_loss: 0.7736
# Epoch 21/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9852 - loss: 0.2955 - val_accuracy: 0.9770 - val_loss: 0.7665
# Epoch 22/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 11s 131ms/step - accuracy: 0.9887 - loss: 0.2514 - val_accuracy: 0.9780 - val_loss: 0.7575
# Epoch 23/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 9s 120ms/step - accuracy: 0.9859 - loss: 0.2719 - val_accuracy: 0.9780 - val_loss: 0.7585
# Epoch 24/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9847 - loss: 0.2581 - val_accuracy: 0.9780 - val_loss: 0.7595
# Epoch 25/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9808 - loss: 0.2755 - val_accuracy: 0.9760 - val_loss: 0.7678
# Epoch 26/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9840 - loss: 0.1645 - val_accuracy: 0.9740 - val_loss: 0.7745
# Epoch 27/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 123ms/step - accuracy: 0.9832 - loss: 0.1913 - val_accuracy: 0.9780 - val_loss: 0.7655
# Epoch 28/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 121ms/step - accuracy: 0.9835 - loss: 0.2239 - val_accuracy: 0.9780 - val_loss: 0.7674
# Epoch 29/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 8s 121ms/step - accuracy: 0.9865 - loss: 0.2889 - val_accuracy: 0.9780 - val_loss: 0.7661
# Epoch 30/30
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 10s 122ms/step - accuracy: 0.9811 - loss: 0.2018 - val_accuracy: 0.9780 - val_loss: 0.7625

# %%
plot_history(history) # note the scale, loss: high .97-8, accuracy: low 0.8-0.3

# %%
model = tf.keras.models.load_model(MODELS_DIR / "fine_tuning.keras")
test_loss, test_acc = model.evaluate(test_dataset, verbose=0)
print(f"Test accuracy: {test_acc:.3f}")
# Out:
# Test accuracy: 0.967

# %% [markdown]
# ### Save models to Google Drive

# %%
EXPORT=False

if EXPORT:
    # zip models
    # !zip dogs-vs-cats.models.zip {MODELS_DIR}/*
    # connect to drive
    from google.colab import drive
    drive.mount('/content/drive')
    # copy zip to drive (adjust folder as needed)
    # !cp dogs-vs-cats.models.zip drive/MyDrive/IS53024B-Artificial-Intelligence/models

# %% [markdown]
# ----
#
# ## 8.3.3 Wrapping up

# %% [markdown]
# #### Convnets

# %% [markdown]
# - **Conv2D** operation, **kernel**, **filter**, **feature maps**;
# - **Stride**, **padding** (**same**/**valid**);
# - **Max-Pooling** operation;
# - Far fewer parameters than dense networks!
# - A prime-choice machine learning models for computer vision tasks.

# %% [markdown]
# #### Workflows

# %% [markdown]
# - **Data augmentation**: helps with overfitting on small datasets;
# - **Feature extraction**: using features from a pretrained network also helps with overfitting, two flavours:
#    -  only train the top classifier: fast but no augmentation;
#    -  train new top classifier with frozen net: more expensive, better;
# - **Fine-tune upper layers of pretrained net**: (only with a newly trained top classifier), even better performance;
