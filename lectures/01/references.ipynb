# %% [markdown]
# # References | 1. Artificial Intelligence, machine learning, and deep learning

# %% [markdown]
# ## 3Blue1Brown Series

# %% [markdown]
# [3Blue1Brown Series](https://www.youtube.com/embed/videoseries?si=aioJsM2GCOEE-sFC&amp;list=PLZHQObOWTQDNU6R1_67000Dx_ZCJB-3pi)

# %% [markdown]
# ## Slime Mould

# %% [markdown]
# Slime mould is able to find shortest paths between nodes as it searches for food.
#
# [Slime mould BBC](https://www.youtube.com/watch?v=HyzT5b0tNtk)
# [Slime mould Wired](https://www.youtube.com/watch?v=7YWbY7kWesI)

# %% [markdown]
# ## LeCake

# %% [markdown]
# For those of you who are curious, I included here the recording of when LeCun presents this slide for the first time, saying he got a lot of flak for it, and apologising.
#
# [LeCun LeCake](https://www.youtube.com/watch?v=Ount2Y4qxQo&t=1154)

# %% [markdown]
# ## OECD Investment in AI

# %% [markdown]
# <!-- <img src="images/investment/chollet.oecd-2017-investment.png" style="height:700px"> -->
# <img src="https://raw.githubusercontent.com/jchwenger/AI/main/lectures/01/images/investment/chollet.oecd-2017-investment.png" style="height:700px">
#
# <small>DLWP, p.23</small>

# %% [markdown]
# <!-- <img src="images/investment/oecd-2025-investment.png" style="height:700px"> -->
# <img src="https://raw.githubusercontent.com/jchwenger/AI/main/lectures/01/images/investment/oecd-2025-investment.png" style="height:700px">
#
# <small>Source: [OECD AI](https://oecd.ai/en/data?selectedArea=investments-in-ai-and-data&selectedVisualization=worldwide-vc-investments-in-ai)</small>

# %% [markdown]
# ## AI History videos

# %% [markdown]
# [The Thinking Machine (Artificial Intelligence in the 1960s)](https://www.youtube.com/watch?v=aygSMgK3BEM)
# [The Lighthill debate on Artificial Intelligence (1973): "The general purpose robot is a mirage"](https://www.youtube.com/watch?v=03p2CADwGF8)
# [Convolutional Network Demo from 1993](https://www.youtube.com/watch?v=FwFduRA_L6Q)
# [Deep Blue 1997](https://www.youtube.com/watch?v=NJarxpYyoFI)
# [AlphaGo Official Trailer 2017](https://www.youtube.com/watch?v=WXuK6gekU1Y)
# [Chris Bishop AI 2017](https://www.youtube.com/watch?v=8FHBh_OmdsM)
